# %%
# Retrieving multiple parameter values
# https://pythonic.rapellys.biz/articles/working-with-ros-parameters-and-configuration-files-using-python/

# !rosparam get /
# Out:
# arbotix:
#   baud: 115200
#   controllers:
#     base_controller:
#       Kd: 12
#       Ki: 0
#       Ko: 50
#       Kp: 12
#       accel_limit: 1.0
#       base_frame_id: base_footprint
#       base_width: 0.26
#       ticks_meter: 4100
#       type: diff_controller
#   port: /dev/ttyUSB0
#   rate: 20
#   read_rate: 20
#   sim: true
#   sync_read: true
#   sync_write: true
#   write_rate: 20
# move_base:
#   TrajectoryPlannerROS:
#     acc_lim_theta: 1.2
#     acc_lim_x: 1.5
#     acc_lim_y: 0.0
#     angular_sim_granularity: 0.1
#     dwa: true
#     escape_reset_dist: 0.1
#     escape_reset_theta: 1.5707963267948966
#     escape_vel: -0.1
#     gdist_scale: 0.8
#     goal_distance_bias: 0.8
#     heading_lookahead: 0.325
#     heading_scoring: false
#     heading_scoring_timestep: 0.8
#     holonomic_robot: false
#     latch_xy_goal_tolerance: false
#     max_vel_theta: 1.0
#     max_vel_x: 0.5
#     max_vel_y: 0.0
#     meter_scoring: true
#     min_in_place_vel_theta: 0.4
#     min_vel_theta: -1.0
#     min_vel_x: 0.1
#     min_vel_y: 0.0
#     occdist_scale: 0.05
#     oscillation_reset_dist: 0.05
#     path_distance_bias: 0.4
#     pdist_scale: 0.4
#     prune_plan: true
#     publish_cost_grid_pc: false
#     restore_defaults: false
#     sim_granularity: 0.05
#     sim_time: 1.0
#     simple_attractor: false
#     vtheta_samples: 20
#     vx_samples: 8
#     vy_samples: 0
#     xy_goal_tolerance: 0.05
#     y_vels: -0.3,-0.1,0.1,-0.3
#     yaw_goal_tolerance: 0.1
#   aggressive_reset:
#     reset_distance: 1.84
#   base_global_planner: navfn/NavfnROS
#   base_local_planner: base_local_planner/TrajectoryPlannerROS
#   clearing_rotation_allowed: false
#   conservative_reset:
#     reset_distance: 3.0
#   conservative_reset_dist: 3.0
#   controller_frequency: 3.0
#   controller_patience: 5.0
#   global_costmap:
#     footprint: '[]'
#     footprint_padding: 0.01
#     global_frame: map
#     height: 10
#     inflation_layer:
#       cost_scaling_factor: 10.0
#       enabled: true
#       inflate_unknown: false
#       inflation_radius: 0.1
#     map_type: costmap
#     min_obstacle_height: 0.0
#     obstacle_layer:
#       combination_method: 1
#       enabled: true
#       footprint_clearing_enabled: true
#       max_obstacle_height: 0.6
#       observation_sources: scan
#       obstacle_range: 2.5
#       raytrace_range: 3.0
#       scan:
#         clearing: true
#         data_type: LaserScan
#         expected_update_rate: 0
#         marking: true
#         topic: /scan
#     origin_x: 0.0
#     origin_y: 0.0
#     plugins:
#     - name: static_layer
#       type: costmap_2d::StaticLayer
#     - name: obstacle_layer
#       type: costmap_2d::ObstacleLayer
#     - name: inflation_layer
#       type: costmap_2d::InflationLayer
#     publish_frequency: 1.0
#     resolution: 0.01
#     robot_base_frame: base_footprint
#     robot_radius: 0.175
#     rolling_window: false
#     static_layer:
#       enabled: true
#     static_map: true
#     transform_tolerance: 1.0
#     update_frequency: 1.0
#     width: 10
#   local_costmap:
#     footprint: '[]'
#     footprint_padding: 0.01
#     global_frame: map
#     height: 6
#     inflation_layer:
#       cost_scaling_factor: 10.0
#       enabled: true
#       inflate_unknown: false
#       inflation_radius: 0.1
#     min_obstacle_height: 0.0
#     obstacle_layer:
#       combination_method: 1
#       enabled: true
#       footprint_clearing_enabled: true
#       max_obstacle_height: 0.6
#       observation_sources: scan
#       obstacle_range: 2.5
#       raytrace_range: 3.0
#       scan:
#         clearing: true
#         data_type: LaserScan
#         expected_update_rate: 0
#         marking: true
#         topic: /scan
#     origin_x: 0.0
#     origin_y: 0.0
#     plugins:
#     - name: static_layer
#       type: costmap_2d::StaticLayer
#     - name: obstacle_layer
#       type: costmap_2d::ObstacleLayer
#     - name: inflation_layer
#       type: costmap_2d::InflationLayer
#     publish_frequency: 1.0
#     resolution: 0.01
#     robot_base_frame: base_footprint
#     robot_radius: 0.175
#     rolling_window: false
#     static_layer:
#       enabled: true
#     static_map: true
#     transform_tolerance: 1.0
#     update_frequency: 3.0
#     width: 6
#   make_plan_add_unreachable_goal: true
#   make_plan_clear_costmap: true
#   max_planning_retries: -1
#   oscillation_distance: 0.5
#   oscillation_timeout: 0.0
#   planner_frequency: 0.0
#   planner_patience: 5.0
#   recovery_behavior_enabled: false
#   restore_defaults: false
#   shutdown_costmaps: false
# robot_description: "<?xml version=\"1.0\" ?>\n<!-- ===================================================================================\
#   \ -->\n<!-- |    This document was autogenerated by xacro from /home/orangepi/catkin_ws/src/mrobot_description/urdf/mrobot_with_rplidar.urdf.xacro\
#   \ | -->\n<!-- |    EDITING THIS FILE BY HAND IS NOT RECOMMENDED                \
#   \                 | -->\n<!-- ===================================================================================\
#   \ -->\n<robot name=\"mrobot\">\n  <material name=\"Green\">\n    <color rgba=\"\
#   0.0 0.8 0.0 1.0\"/>\n  </material>\n  <material name=\"yellow\">\n    <color rgba=\"\
#   1 0.4 0 1\"/>\n  </material>\n  <material name=\"black\">\n    <color rgba=\"0 0\
#   \ 0 0.95\"/>\n  </material>\n  <material name=\"gray\">\n    <color rgba=\"0.75\
#   \ 0.75 0.75 1\"/>\n  </material>\n  <link name=\"base_footprint\">\n    <visual>\n\
#   \      <origin rpy=\"0 0 0\" xyz=\"0 0 0\"/>\n      <geometry>\n        <box size=\"\
#   0.001 0.001 0.001\"/>\n      </geometry>\n    </visual>\n  </link>\n  <link name=\"\
#   base_link\">\n    <inertial>\n      <mass value=\"2\"/>\n      <origin xyz=\"0 0\
#   \ 0.0\"/>\n      <inertia ixx=\"0.01\" ixy=\"0.0\" ixz=\"0.0\" iyy=\"0.01\" iyz=\"\
#   0.0\" izz=\"0.5\"/>\n    </inertial>\n    <visual>\n      <origin rpy=\"0 0 0\"\
#   \ xyz=\" 0 0 0\"/>\n      <geometry>\n        <cylinder length=\"0.005\" radius=\"\
#   0.13\"/>\n      </geometry>\n      <material name=\"yellow\"/>\n    </visual>\n\
#   \    <collision>\n      <origin rpy=\"0 0 0\" xyz=\"0 0 0\"/>\n      <geometry>\n\
#   \        <cylinder length=\"0.005\" radius=\"0.13\"/>\n      </geometry>\n    </collision>\n\
#   \  </link>\n  <joint name=\"base_footprint_joint\" type=\"fixed\">\n    <origin\
#   \ rpy=\"0 0 0\" xyz=\"0 0 0.033\"/>\n    <parent link=\"base_footprint\"/>\n   \
#   \ <child link=\"base_link\"/>\n  </joint>\n  <link name=\"left_motor\">\n    <inertial>\n\
#   \      <origin xyz=\"0.0 0 0\"/>\n      <mass value=\"0.1\"/>\n      <inertia ixx=\"\
#   0.001\" ixy=\"0.0\" ixz=\"0.0\" iyy=\"0.001\" iyz=\"0.0\" izz=\"0.001\"/>\n    </inertial>\n\
#   \    <visual>\n      <origin rpy=\"1.570795 0 0\" xyz=\"0 0 0\"/>\n      <geometry>\n\
#   \        <cylinder length=\"0.08\" radius=\"0.02\"/>\n      </geometry>\n      <material\
#   \ name=\"gray\"/>\n    </visual>\n    <collision>\n      <origin rpy=\"1.570795\
#   \ 0 0\" xyz=\"0 0 0\"/>\n      <geometry>\n        <cylinder length=\"0.08\" radius=\"\
#   0.02\"/>\n      </geometry>\n    </collision>\n  </link>\n  <joint name=\"base_left_motor_joint\"\
#   \ type=\"fixed\">\n    <origin rpy=\"0 0 0\" xyz=\"-0.055 0.075 0\"/>\n    <parent\
#   \ link=\"base_link\"/>\n    <child link=\"left_motor\"/>\n  </joint>\n  <link name=\"\
#   left_wheel_link\">\n    <inertial>\n      <origin xyz=\"0 0 0\"/>\n      <mass value=\"\
#   0.01\"/>\n      <inertia ixx=\"0.001\" ixy=\"0.0\" ixz=\"0.0\" iyy=\"0.001\" iyz=\"\
#   0.0\" izz=\"0.001\"/>\n    </inertial>\n    <visual>\n      <origin rpy=\"1.570795\
#   \ 0 0\" xyz=\"0 0 0\"/>\n      <geometry>\n        <cylinder length=\"0.017\" radius=\"\
#   0.033\"/>\n      </geometry>\n      <material name=\"white\">\n        <color rgba=\"\
#   1 1 1 0.9\"/>\n      </material>\n    </visual>\n    <collision>\n      <origin\
#   \ rpy=\"1.570795 0 0\" xyz=\"0 0 0\"/>\n      <geometry>\n        <cylinder length=\"\
#   0.017\" radius=\"0.033\"/>\n      </geometry>\n    </collision>\n  </link>\n  <joint\
#   \ name=\"left_wheel_joint\" type=\"continuous\">\n    <origin rpy=\"0 0 0\" xyz=\"\
#   0 0.0485 0\"/>\n    <parent link=\"left_motor\"/>\n    <child link=\"left_wheel_link\"\
#   />\n    <axis xyz=\"0 1 0\"/>\n  </joint>\n  <link name=\"right_motor\">\n    <inertial>\n\
#   \      <origin xyz=\"0.0 0 0\"/>\n      <mass value=\"0.1\"/>\n      <inertia ixx=\"\
#   0.001\" ixy=\"0.0\" ixz=\"0.0\" iyy=\"0.001\" iyz=\"0.0\" izz=\"0.001\"/>\n    </inertial>\n\
#   \    <visual>\n      <origin rpy=\"1.570795 0 0\" xyz=\"0 0 0\"/>\n      <geometry>\n\
#   \        <cylinder length=\"0.08\" radius=\"0.02\"/>\n      </geometry>\n      <material\
#   \ name=\"gray\"/>\n    </visual>\n    <collision>\n      <origin rpy=\"1.570795\
#   \ 0 0\" xyz=\"0 0 0\"/>\n      <geometry>\n        <cylinder length=\"0.08\" radius=\"\
#   0.02\"/>\n      </geometry>\n    </collision>\n  </link>\n  <joint name=\"base_right_motor_joint\"\
#   \ type=\"fixed\">\n    <origin rpy=\"0 0 0\" xyz=\"-0.055 -0.075 0\"/>\n    <parent\
#   \ link=\"base_link\"/>\n    <child link=\"right_motor\"/>\n  </joint>\n  <link name=\"\
#   right_wheel_link\">\n    <inertial>\n      <origin xyz=\"0 0 0\"/>\n      <mass\
#   \ value=\"0.01\"/>\n      <inertia ixx=\"0.001\" ixy=\"0.0\" ixz=\"0.0\" iyy=\"\
#   0.001\" iyz=\"0.0\" izz=\"0.001\"/>\n    </inertial>\n    <visual>\n      <origin\
#   \ rpy=\"1.570795 0 0\" xyz=\"0 0 0\"/>\n      <geometry>\n        <cylinder length=\"\
#   0.017\" radius=\"0.033\"/>\n      </geometry>\n      <material name=\"white\">\n\
#   \        <color rgba=\"1 1 1 0.9\"/>\n      </material>\n    </visual>\n    <collision>\n\
#   \      <origin rpy=\"1.570795 0 0\" xyz=\"0 0 0\"/>\n      <geometry>\n        <cylinder\
#   \ length=\"0.017\" radius=\"0.033\"/>\n      </geometry>\n    </collision>\n  </link>\n\
#   \  <joint name=\"right_wheel_joint\" type=\"continuous\">\n    <origin rpy=\"0 0\
#   \ 0\" xyz=\"0 -0.0485 0\"/>\n    <parent link=\"right_motor\"/>\n    <child link=\"\
#   right_wheel_link\"/>\n    <axis xyz=\"0 1 0\"/>\n  </joint>\n  <link name=\"front_caster_link\"\
#   >\n    <inertial>\n      <origin xyz=\"0 0 0\"/>\n      <mass value=\"0.001\"/>\n\
#   \      <inertia ixx=\"0.0001\" ixy=\"0.0\" ixz=\"0.0\" iyy=\"0.0001\" iyz=\"0.0\"\
#   \ izz=\"0.0001\"/>\n    </inertial>\n    <visual>\n      <origin rpy=\"1.570795\
#   \ 0 0\" xyz=\"0 0 0\"/>\n      <geometry>\n        <sphere radius=\"0.0165\"/>\n\
#   \      </geometry>\n      <material name=\"black\"/>\n    </visual>\n    <collision>\n\
#   \      <origin rpy=\"1.570795 0 0\" xyz=\"0 0 0.01\"/>\n      <geometry>\n     \
#   \   <sphere radius=\"0.0165\"/>\n      </geometry>\n    </collision>\n  </link>\n\
#   \  <joint name=\"front_caster_joint\" type=\"fixed\">\n    <origin rpy=\"0 0 0\"\
#   \ xyz=\"0.1135 0 -0.0165\"/>\n    <parent link=\"base_link\"/>\n    <child link=\"\
#   front_caster_link\"/>\n  </joint>\n  <joint name=\"standoff_2in_1_joint\" type=\"\
#   fixed\">\n    <origin rpy=\"0 0 0\" xyz=\"-0.09 -0.07 0.035\"/>\n    <parent link=\"\
#   base_link\"/>\n    <child link=\"standoff_2in_1_link\"/>\n  </joint>\n  <link name=\"\
#   standoff_2in_1_link\">\n    <inertial>\n      <mass value=\"0.001\"/>\n      <origin\
#   \ xyz=\"0 0 0\"/>\n      <inertia ixx=\"0.0001\" ixy=\"0.0\" ixz=\"0.0\" iyy=\"\
#   0.0001\" iyz=\"0.0\" izz=\"0.0001\"/>\n    </inertial>\n    <visual>\n      <origin\
#   \ rpy=\"0 0 0\" xyz=\" 0 0 0 \"/>\n      <geometry>\n        <box size=\"0.01 0.01\
#   \ 0.07\"/>\n      </geometry>\n      <material name=\"black\">\n        <color rgba=\"\
#   0.16 0.17 0.15 0.9\"/>\n      </material>\n    </visual>\n    <collision>\n    \
#   \  <origin rpy=\"0 0 0\" xyz=\"0.0 0.0 0.0\"/>\n      <geometry>\n        <box size=\"\
#   0.01 0.01 0.07\"/>\n      </geometry>\n    </collision>\n  </link>\n  <joint name=\"\
#   standoff_2in_2_joint\" type=\"fixed\">\n    <origin rpy=\"0 0 0\" xyz=\"-0.09 0.07\
#   \ 0.035\"/>\n    <parent link=\"base_link\"/>\n    <child link=\"standoff_2in_2_link\"\
#   />\n  </joint>\n  <link name=\"standoff_2in_2_link\">\n    <inertial>\n      <mass\
#   \ value=\"0.001\"/>\n      <origin xyz=\"0 0 0\"/>\n      <inertia ixx=\"0.0001\"\
#   \ ixy=\"0.0\" ixz=\"0.0\" iyy=\"0.0001\" iyz=\"0.0\" izz=\"0.0001\"/>\n    </inertial>\n\
#   \    <visual>\n      <origin rpy=\"0 0 0\" xyz=\" 0 0 0 \"/>\n      <geometry>\n\
#   \        <box size=\"0.01 0.01 0.07\"/>\n      </geometry>\n      <material name=\"\
#   black\">\n        <color rgba=\"0.16 0.17 0.15 0.9\"/>\n      </material>\n    </visual>\n\
#   \    <collision>\n      <origin rpy=\"0 0 0\" xyz=\"0.0 0.0 0.0\"/>\n      <geometry>\n\
#   \        <box size=\"0.01 0.01 0.07\"/>\n      </geometry>\n    </collision>\n \
#   \ </link>\n  <joint name=\"standoff_2in_3_joint\" type=\"fixed\">\n    <origin rpy=\"\
#   0 0 0\" xyz=\"0.06 -0.1 0.035\"/>\n    <parent link=\"base_link\"/>\n    <child\
#   \ link=\"standoff_2in_3_link\"/>\n  </joint>\n  <link name=\"standoff_2in_3_link\"\
#   >\n    <inertial>\n      <mass value=\"0.001\"/>\n      <origin xyz=\"0 0 0\"/>\n\
#   \      <inertia ixx=\"0.0001\" ixy=\"0.0\" ixz=\"0.0\" iyy=\"0.0001\" iyz=\"0.0\"\
#   \ izz=\"0.0001\"/>\n    </inertial>\n    <visual>\n      <origin rpy=\"0 0 0\" xyz=\"\
#   \ 0 0 0 \"/>\n      <geometry>\n        <box size=\"0.01 0.01 0.07\"/>\n      </geometry>\n\
#   \      <material name=\"black\">\n        <color rgba=\"0.16 0.17 0.15 0.9\"/>\n\
#   \      </material>\n    </visual>\n    <collision>\n      <origin rpy=\"0 0 0\"\
#   \ xyz=\"0.0 0.0 0.0\"/>\n      <geometry>\n        <box size=\"0.01 0.01 0.07\"\
#   />\n      </geometry>\n    </collision>\n  </link>\n  <joint name=\"standoff_2in_4_joint\"\
#   \ type=\"fixed\">\n    <origin rpy=\"0 0 0\" xyz=\"0.06 0.1 0.035\"/>\n    <parent\
#   \ link=\"base_link\"/>\n    <child link=\"standoff_2in_4_link\"/>\n  </joint>\n\
#   \  <link name=\"standoff_2in_4_link\">\n    <inertial>\n      <mass value=\"0.001\"\
#   />\n      <origin xyz=\"0 0 0\"/>\n      <inertia ixx=\"0.0001\" ixy=\"0.0\" ixz=\"\
#   0.0\" iyy=\"0.0001\" iyz=\"0.0\" izz=\"0.0001\"/>\n    </inertial>\n    <visual>\n\
#   \      <origin rpy=\"0 0 0\" xyz=\" 0 0 0 \"/>\n      <geometry>\n        <box size=\"\
#   0.01 0.01 0.07\"/>\n      </geometry>\n      <material name=\"black\">\n       \
#   \ <color rgba=\"0.16 0.17 0.15 0.9\"/>\n      </material>\n    </visual>\n    <collision>\n\
#   \      <origin rpy=\"0 0 0\" xyz=\"0.0 0.0 0.0\"/>\n      <geometry>\n        <box\
#   \ size=\"0.01 0.01 0.07\"/>\n      </geometry>\n    </collision>\n  </link>\n  <joint\
#   \ name=\"plate_1_joint\" type=\"fixed\">\n    <origin rpy=\"0 0 0\" xyz=\"0 0 0.07\"\
#   />\n    <parent link=\"base_link\"/>\n    <child link=\"plate_1_link\"/>\n  </joint>\n\
#   \  <link name=\"plate_1_link\">\n    <inertial>\n      <mass value=\"0.1\"/>\n \
#   \     <origin xyz=\"0 0 0\"/>\n      <inertia ixx=\"0.01\" ixy=\"0.0\" ixz=\"0.0\"\
#   \ iyy=\"0.01\" iyz=\"0.0\" izz=\"0.01\"/>\n    </inertial>\n    <visual>\n     \
#   \ <origin rpy=\"0 0 0\" xyz=\" 0 0 0 \"/>\n      <geometry>\n        <cylinder length=\"\
#   0.005\" radius=\"0.13\"/>\n      </geometry>\n      <material name=\"yellow\"/>\n\
#   \    </visual>\n    <collision>\n      <origin rpy=\"0 0 0\" xyz=\"0.0 0.0 0.0\"\
#   />\n      <geometry>\n        <cylinder length=\"0.005\" radius=\"0.13\"/>\n   \
#   \   </geometry>\n    </collision>\n  </link>\n  <joint name=\"standoff_2in_5_joint\"\
#   \ type=\"fixed\">\n    <origin rpy=\"0 0 0\" xyz=\"0 0 0.07\"/>\n    <parent link=\"\
#   standoff_2in_1_link\"/>\n    <child link=\"standoff_2in_5_link\"/>\n  </joint>\n\
#   \  <link name=\"standoff_2in_5_link\">\n    <inertial>\n      <mass value=\"0.001\"\
#   />\n      <origin xyz=\"0 0 0\"/>\n      <inertia ixx=\"0.0001\" ixy=\"0.0\" ixz=\"\
#   0.0\" iyy=\"0.0001\" iyz=\"0.0\" izz=\"0.0001\"/>\n    </inertial>\n    <visual>\n\
#   \      <origin rpy=\"0 0 0\" xyz=\" 0 0 0 \"/>\n      <geometry>\n        <box size=\"\
#   0.01 0.01 0.07\"/>\n      </geometry>\n      <material name=\"black\">\n       \
#   \ <color rgba=\"0.16 0.17 0.15 0.9\"/>\n      </material>\n    </visual>\n    <collision>\n\
#   \      <origin rpy=\"0 0 0\" xyz=\"0.0 0.0 0.0\"/>\n      <geometry>\n        <box\
#   \ size=\"0.01 0.01 0.07\"/>\n      </geometry>\n    </collision>\n  </link>\n  <joint\
#   \ name=\"standoff_2in_6_joint\" type=\"fixed\">\n    <origin rpy=\"0 0 0\" xyz=\"\
#   0 0 0.07\"/>\n    <parent link=\"standoff_2in_2_link\"/>\n    <child link=\"standoff_2in_6_link\"\
#   />\n  </joint>\n  <link name=\"standoff_2in_6_link\">\n    <inertial>\n      <mass\
#   \ value=\"0.001\"/>\n      <origin xyz=\"0 0 0\"/>\n      <inertia ixx=\"0.0001\"\
#   \ ixy=\"0.0\" ixz=\"0.0\" iyy=\"0.0001\" iyz=\"0.0\" izz=\"0.0001\"/>\n    </inertial>\n\
#   \    <visual>\n      <origin rpy=\"0 0 0\" xyz=\" 0 0 0 \"/>\n      <geometry>\n\
#   \        <box size=\"0.01 0.01 0.07\"/>\n      </geometry>\n      <material name=\"\
#   black\">\n        <color rgba=\"0.16 0.17 0.15 0.9\"/>\n      </material>\n    </visual>\n\
#   \    <collision>\n      <origin rpy=\"0 0 0\" xyz=\"0.0 0.0 0.0\"/>\n      <geometry>\n\
#   \        <box size=\"0.01 0.01 0.07\"/>\n      </geometry>\n    </collision>\n \
#   \ </link>\n  <joint name=\"standoff_2in_7_joint\" type=\"fixed\">\n    <origin rpy=\"\
#   0 0 0\" xyz=\"0 0 0.07\"/>\n    <parent link=\"standoff_2in_3_link\"/>\n    <child\
#   \ link=\"standoff_2in_7_link\"/>\n  </joint>\n  <link name=\"standoff_2in_7_link\"\
#   >\n    <inertial>\n      <mass value=\"0.001\"/>\n      <origin xyz=\"0 0 0\"/>\n\
#   \      <inertia ixx=\"0.0001\" ixy=\"0.0\" ixz=\"0.0\" iyy=\"0.0001\" iyz=\"0.0\"\
#   \ izz=\"0.0001\"/>\n    </inertial>\n    <visual>\n      <origin rpy=\"0 0 0\" xyz=\"\
#   \ 0 0 0 \"/>\n      <geometry>\n        <box size=\"0.01 0.01 0.07\"/>\n      </geometry>\n\
#   \      <material name=\"black\">\n        <color rgba=\"0.16 0.17 0.15 0.9\"/>\n\
#   \      </material>\n    </visual>\n    <collision>\n      <origin rpy=\"0 0 0\"\
#   \ xyz=\"0.0 0.0 0.0\"/>\n      <geometry>\n        <box size=\"0.01 0.01 0.07\"\
#   />\n      </geometry>\n    </collision>\n  </link>\n  <joint name=\"standoff_2in_8_joint\"\
#   \ type=\"fixed\">\n    <origin rpy=\"0 0 0\" xyz=\"0 0 0.07\"/>\n    <parent link=\"\
#   standoff_2in_4_link\"/>\n    <child link=\"standoff_2in_8_link\"/>\n  </joint>\n\
#   \  <link name=\"standoff_2in_8_link\">\n    <inertial>\n      <mass value=\"0.001\"\
#   />\n      <origin xyz=\"0 0 0\"/>\n      <inertia ixx=\"0.0001\" ixy=\"0.0\" ixz=\"\
#   0.0\" iyy=\"0.0001\" iyz=\"0.0\" izz=\"0.0001\"/>\n    </inertial>\n    <visual>\n\
#   \      <origin rpy=\"0 0 0\" xyz=\" 0 0 0 \"/>\n      <geometry>\n        <box size=\"\
#   0.01 0.01 0.07\"/>\n      </geometry>\n      <material name=\"black\">\n       \
#   \ <color rgba=\"0.16 0.17 0.15 0.9\"/>\n      </material>\n    </visual>\n    <collision>\n\
#   \      <origin rpy=\"0 0 0\" xyz=\"0.0 0.0 0.0\"/>\n      <geometry>\n        <box\
#   \ size=\"0.01 0.01 0.07\"/>\n      </geometry>\n    </collision>\n  </link>\n  <joint\
#   \ name=\"plate_2_joint\" type=\"fixed\">\n    <origin rpy=\"0 0 0\" xyz=\"0 0 0.07\"\
#   />\n    <parent link=\"plate_1_link\"/>\n    <child link=\"plate_2_link\"/>\n  </joint>\n\
#   \  <link name=\"plate_2_link\">\n    <inertial>\n      <mass value=\"0.01\"/>\n\
#   \      <origin xyz=\"0 0 0\"/>\n      <inertia ixx=\"0.001\" ixy=\"0.0\" ixz=\"\
#   0.0\" iyy=\"0.001\" iyz=\"0.0\" izz=\"0.001\"/>\n    </inertial>\n    <visual>\n\
#   \      <origin rpy=\"0 0 0\" xyz=\" 0 0 0 \"/>\n      <geometry>\n        <cylinder\
#   \ length=\"0.005\" radius=\"0.13\"/>\n      </geometry>\n      <material name=\"\
#   yellow\"/>\n    </visual>\n    <collision>\n      <origin rpy=\"0 0 0\" xyz=\"0.0\
#   \ 0.0 0.0\"/>\n      <geometry>\n        <cylinder length=\"0.005\" radius=\"0.13\"\
#   />\n      </geometry>\n    </collision>\n  </link>\n  <!-- rplidar -->\n  <joint\
#   \ name=\"rplidar_joint\" type=\"fixed\">\n    <origin rpy=\"0 0 0\" xyz=\"0 0 0.028\"\
#   />\n    <parent link=\"plate_2_link\"/>\n    <child link=\"laser_link\"/>\n  </joint>\n\
#   \  <link name=\"laser_link\">\n    <inertial>\n      <mass value=\"0.1\"/>\n   \
#   \   <origin xyz=\"0 0 0\"/>\n      <inertia ixx=\"0.01\" ixy=\"0.0\" ixz=\"0.0\"\
#   \ iyy=\"0.01\" iyz=\"0.0\" izz=\"0.01\"/>\n    </inertial>\n    <visual>\n     \
#   \ <origin rpy=\"0 0 0\" xyz=\" 0 0 0 \"/>\n      <geometry>\n        <cylinder length=\"\
#   0.05\" radius=\"0.05\"/>\n      </geometry>\n      <material name=\"black\"/>\n\
#   \    </visual>\n    <collision>\n      <origin rpy=\"0 0 0\" xyz=\"0.0 0.0 0.0\"\
#   />\n      <geometry>\n        <cylinder length=\"0.06\" radius=\"0.05\"/>\n    \
#   \  </geometry>\n    </collision>\n  </link>\n</robot>\n\n"
# robot_state_publisher:
#   publish_frequency: 20.0
# rosdistro: 'noetic
#
#   '
# roslaunch:
#   uris:
#     host_orangepi4_lts__35621: http://orangepi4-lts:35621/
#     host_orangepi4_lts__37893: http://orangepi4-lts:37893/
# rosversion: '1.16.0
#
#   '
# run_id: 26b0fa54-a3ea-11ef-9b86-24b72a46412d
# use_sim_time: false

# %%
# !rosparam list
# Out:
# /arbotix/baud
# /arbotix/controllers/base_controller/Kd
# /arbotix/controllers/base_controller/Ki
# /arbotix/controllers/base_controller/Ko
# /arbotix/controllers/base_controller/Kp
# /arbotix/controllers/base_controller/accel_limit
# /arbotix/controllers/base_controller/base_frame_id
# /arbotix/controllers/base_controller/base_width
# /arbotix/controllers/base_controller/ticks_meter
# /arbotix/controllers/base_controller/type
# /arbotix/port
# /arbotix/rate
# /arbotix/read_rate
# /arbotix/sim
# /arbotix/sync_read
# /arbotix/sync_write
# /arbotix/write_rate
# /move_base/TrajectoryPlannerROS/acc_lim_theta
# /move_base/TrajectoryPlannerROS/acc_lim_x
# /move_base/TrajectoryPlannerROS/acc_lim_y
# /move_base/TrajectoryPlannerROS/angular_sim_granularity
# /move_base/TrajectoryPlannerROS/dwa
# /move_base/TrajectoryPlannerROS/escape_reset_dist
# /move_base/TrajectoryPlannerROS/escape_reset_theta
# /move_base/TrajectoryPlannerROS/escape_vel
# /move_base/TrajectoryPlannerROS/gdist_scale
# /move_base/TrajectoryPlannerROS/goal_distance_bias
# /move_base/TrajectoryPlannerROS/heading_lookahead
# /move_base/TrajectoryPlannerROS/heading_scoring
# /move_base/TrajectoryPlannerROS/heading_scoring_timestep
# /move_base/TrajectoryPlannerROS/holonomic_robot
# /move_base/TrajectoryPlannerROS/latch_xy_goal_tolerance
# /move_base/TrajectoryPlannerROS/max_vel_theta
# /move_base/TrajectoryPlannerROS/max_vel_x
# /move_base/TrajectoryPlannerROS/max_vel_y
# /move_base/TrajectoryPlannerROS/meter_scoring
# /move_base/TrajectoryPlannerROS/min_in_place_vel_theta
# /move_base/TrajectoryPlannerROS/min_vel_theta
# /move_base/TrajectoryPlannerROS/min_vel_x
# /move_base/TrajectoryPlannerROS/min_vel_y
# /move_base/TrajectoryPlannerROS/occdist_scale
# /move_base/TrajectoryPlannerROS/oscillation_reset_dist
# /move_base/TrajectoryPlannerROS/path_distance_bias
# /move_base/TrajectoryPlannerROS/pdist_scale
# /move_base/TrajectoryPlannerROS/prune_plan
# /move_base/TrajectoryPlannerROS/publish_cost_grid_pc
# /move_base/TrajectoryPlannerROS/restore_defaults
# /move_base/TrajectoryPlannerROS/sim_granularity
# /move_base/TrajectoryPlannerROS/sim_time
# /move_base/TrajectoryPlannerROS/simple_attractor
# /move_base/TrajectoryPlannerROS/vtheta_samples
# /move_base/TrajectoryPlannerROS/vx_samples
# /move_base/TrajectoryPlannerROS/vy_samples
# /move_base/TrajectoryPlannerROS/xy_goal_tolerance
# /move_base/TrajectoryPlannerROS/y_vels
# /move_base/TrajectoryPlannerROS/yaw_goal_tolerance
# /move_base/aggressive_reset/reset_distance
# /move_base/base_global_planner
# /move_base/base_local_planner
# /move_base/clearing_rotation_allowed
# /move_base/conservative_reset/reset_distance
# /move_base/conservative_reset_dist
# /move_base/controller_frequency
# /move_base/controller_patience
# /move_base/global_costmap/footprint
# /move_base/global_costmap/footprint_padding
# /move_base/global_costmap/global_frame
# /move_base/global_costmap/height
# /move_base/global_costmap/inflation_layer/cost_scaling_factor
# /move_base/global_costmap/inflation_layer/enabled
# /move_base/global_costmap/inflation_layer/inflate_unknown
# /move_base/global_costmap/inflation_layer/inflation_radius
# /move_base/global_costmap/map_type
# /move_base/global_costmap/min_obstacle_height
# /move_base/global_costmap/obstacle_layer/combination_method
# /move_base/global_costmap/obstacle_layer/enabled
# /move_base/global_costmap/obstacle_layer/footprint_clearing_enabled
# /move_base/global_costmap/obstacle_layer/max_obstacle_height
# /move_base/global_costmap/obstacle_layer/observation_sources
# /move_base/global_costmap/obstacle_layer/obstacle_range
# /move_base/global_costmap/obstacle_layer/raytrace_range
# /move_base/global_costmap/obstacle_layer/scan/clearing
# /move_base/global_costmap/obstacle_layer/scan/data_type
# /move_base/global_costmap/obstacle_layer/scan/expected_update_rate
# /move_base/global_costmap/obstacle_layer/scan/marking
# /move_base/global_costmap/obstacle_layer/scan/topic
# /move_base/global_costmap/origin_x
# /move_base/global_costmap/origin_y
# /move_base/global_costmap/plugins
# /move_base/global_costmap/publish_frequency
# /move_base/global_costmap/resolution
# /move_base/global_costmap/robot_base_frame
# /move_base/global_costmap/robot_radius
# /move_base/global_costmap/rolling_window
# /move_base/global_costmap/static_layer/enabled
# /move_base/global_costmap/static_map
# /move_base/global_costmap/transform_tolerance
# /move_base/global_costmap/update_frequency
# /move_base/global_costmap/width
# /move_base/local_costmap/footprint
# /move_base/local_costmap/footprint_padding
# /move_base/local_costmap/global_frame
# /move_base/local_costmap/height
# /move_base/local_costmap/inflation_layer/cost_scaling_factor
# /move_base/local_costmap/inflation_layer/enabled
# /move_base/local_costmap/inflation_layer/inflate_unknown
# /move_base/local_costmap/inflation_layer/inflation_radius
# /move_base/local_costmap/min_obstacle_height
# /move_base/local_costmap/obstacle_layer/combination_method
# /move_base/local_costmap/obstacle_layer/enabled
# /move_base/local_costmap/obstacle_layer/footprint_clearing_enabled
# /move_base/local_costmap/obstacle_layer/max_obstacle_height
# /move_base/local_costmap/obstacle_layer/observation_sources
# /move_base/local_costmap/obstacle_layer/obstacle_range
# /move_base/local_costmap/obstacle_layer/raytrace_range
# /move_base/local_costmap/obstacle_layer/scan/clearing
# /move_base/local_costmap/obstacle_layer/scan/data_type
# /move_base/local_costmap/obstacle_layer/scan/expected_update_rate
# /move_base/local_costmap/obstacle_layer/scan/marking
# /move_base/local_costmap/obstacle_layer/scan/topic
# /move_base/local_costmap/origin_x
# /move_base/local_costmap/origin_y
# /move_base/local_costmap/plugins
# /move_base/local_costmap/publish_frequency
# /move_base/local_costmap/resolution
# /move_base/local_costmap/robot_base_frame
# /move_base/local_costmap/robot_radius
# /move_base/local_costmap/rolling_window
# /move_base/local_costmap/static_layer/enabled
# /move_base/local_costmap/static_map
# /move_base/local_costmap/transform_tolerance
# /move_base/local_costmap/update_frequency
# /move_base/local_costmap/width
# /move_base/make_plan_add_unreachable_goal
# /move_base/make_plan_clear_costmap
# /move_base/max_planning_retries
# /move_base/oscillation_distance
# /move_base/oscillation_timeout
# /move_base/planner_frequency
# /move_base/planner_patience
# /move_base/recovery_behavior_enabled
# /move_base/restore_defaults
# /move_base/shutdown_costmaps
# /robot_description
# /robot_state_publisher/publish_frequency
# /rosdistro
# /roslaunch/uris/host_orangepi4_lts__35621
# /roslaunch/uris/host_orangepi4_lts__37893
# /rosversion
# /run_id
# /use_sim_time

# %%
import rospy

# Get all parameter names
param_names = rospy.get_param_names()
#print(*param_names, sep='\n')

# Get the values of all parameters
params = {}
for name in param_names:
    params[name] = rospy.get_param(name)
    print(name, ': ', params[name])
# Out:
# /run_id :  8a100b10-a419-11ef-a1c1-24b72a46412d
# /roslaunch/uris/host_orangepi4_lts__42083 :  http://orangepi4-lts:42083/
# /roslaunch/uris/host_orangepi4_lts__36067 :  http://orangepi4-lts:36067/
# /rosversion :  1.16.0
#
# /rosdistro :  noetic
#
# /use_sim_time :  False
# /robot_description :  <?xml version="1.0" ?>
# <!-- =================================================================================== -->
# <!-- |    This document was autogenerated by xacro from /home/orangepi/catkin_ws/src/mrobot_description/urdf/mrobot_with_rplidar.urdf.xacro | -->
# <!-- |    EDITING THIS FILE BY HAND IS NOT RECOMMENDED                                 | -->
# <!-- =================================================================================== -->
# <robot name="mrobot">
#   <material name="Green">
#     <color rgba="0.0 0.8 0.0 1.0"/>
#   </material>
#   <material name="yellow">
#     <color rgba="1 0.4 0 1"/>
#   </material>
#   <material name="black">
#     <color rgba="0 0 0 0.95"/>
#   </material>
#   <material name="gray">
#     <color rgba="0.75 0.75 0.75 1"/>
#   </material>
#   <link name="base_footprint">
#     <visual>
#       <origin rpy="0 0 0" xyz="0 0 0"/>
#       <geometry>
#         <box size="0.001 0.001 0.001"/>
#       </geometry>
#     </visual>
#   </link>
#   <link name="base_link">
#     <inertial>
#       <mass value="2"/>
#       <origin xyz="0 0 0.0"/>
#       <inertia ixx="0.01" ixy="0.0" ixz="0.0" iyy="0.01" iyz="0.0" izz="0.5"/>
#     </inertial>
#     <visual>
#       <origin rpy="0 0 0" xyz=" 0 0 0"/>
#       <geometry>
#         <cylinder length="0.005" radius="0.13"/>
#       </geometry>
#       <material name="yellow"/>
#     </visual>
#     <collision>
#       <origin rpy="0 0 0" xyz="0 0 0"/>
#       <geometry>
#         <cylinder length="0.005" radius="0.13"/>
#       </geometry>
#     </collision>
#   </link>
#   <joint name="base_footprint_joint" type="fixed">
#     <origin rpy="0 0 0" xyz="0 0 0.033"/>
#     <parent link="base_footprint"/>
#     <child link="base_link"/>
#   </joint>
#   <link name="left_motor">
#     <inertial>
#       <origin xyz="0.0 0 0"/>
#       <mass value="0.1"/>
#       <inertia ixx="0.001" ixy="0.0" ixz="0.0" iyy="0.001" iyz="0.0" izz="0.001"/>
#     </inertial>
#     <visual>
#       <origin rpy="1.570795 0 0" xyz="0 0 0"/>
#       <geometry>
#         <cylinder length="0.08" radius="0.02"/>
#       </geometry>
#       <material name="gray"/>
#     </visual>
#     <collision>
#       <origin rpy="1.570795 0 0" xyz="0 0 0"/>
#       <geometry>
#         <cylinder length="0.08" radius="0.02"/>
#       </geometry>
#     </collision>
#   </link>
#   <joint name="base_left_motor_joint" type="fixed">
#     <origin rpy="0 0 0" xyz="-0.055 0.075 0"/>
#     <parent link="base_link"/>
#     <child link="left_motor"/>
#   </joint>
#   <link name="left_wheel_link">
#     <inertial>
#       <origin xyz="0 0 0"/>
#       <mass value="0.01"/>
#       <inertia ixx="0.001" ixy="0.0" ixz="0.0" iyy="0.001" iyz="0.0" izz="0.001"/>
#     </inertial>
#     <visual>
#       <origin rpy="1.570795 0 0" xyz="0 0 0"/>
#       <geometry>
#         <cylinder length="0.017" radius="0.033"/>
#       </geometry>
#       <material name="white">
#         <color rgba="1 1 1 0.9"/>
#       </material>
#     </visual>
#     <collision>
#       <origin rpy="1.570795 0 0" xyz="0 0 0"/>
#       <geometry>
#         <cylinder length="0.017" radius="0.033"/>
#       </geometry>
#     </collision>
#   </link>
#   <joint name="left_wheel_joint" type="continuous">
#     <origin rpy="0 0 0" xyz="0 0.0485 0"/>
#     <parent link="left_motor"/>
#     <child link="left_wheel_link"/>
#     <axis xyz="0 1 0"/>
#   </joint>
#   <link name="right_motor">
#     <inertial>
#       <origin xyz="0.0 0 0"/>
#       <mass value="0.1"/>
#       <inertia ixx="0.001" ixy="0.0" ixz="0.0" iyy="0.001" iyz="0.0" izz="0.001"/>
#     </inertial>
#     <visual>
#       <origin rpy="1.570795 0 0" xyz="0 0 0"/>
#       <geometry>
#         <cylinder length="0.08" radius="0.02"/>
#       </geometry>
#       <material name="gray"/>
#     </visual>
#     <collision>
#       <origin rpy="1.570795 0 0" xyz="0 0 0"/>
#       <geometry>
#         <cylinder length="0.08" radius="0.02"/>
#       </geometry>
#     </collision>
#   </link>
#   <joint name="base_right_motor_joint" type="fixed">
#     <origin rpy="0 0 0" xyz="-0.055 -0.075 0"/>
#     <parent link="base_link"/>
#     <child link="right_motor"/>
#   </joint>
#   <link name="right_wheel_link">
#     <inertial>
#       <origin xyz="0 0 0"/>
#       <mass value="0.01"/>
#       <inertia ixx="0.001" ixy="0.0" ixz="0.0" iyy="0.001" iyz="0.0" izz="0.001"/>
#     </inertial>
#     <visual>
#       <origin rpy="1.570795 0 0" xyz="0 0 0"/>
#       <geometry>
#         <cylinder length="0.017" radius="0.033"/>
#       </geometry>
#       <material name="white">
#         <color rgba="1 1 1 0.9"/>
#       </material>
#     </visual>
#     <collision>
#       <origin rpy="1.570795 0 0" xyz="0 0 0"/>
#       <geometry>
#         <cylinder length="0.017" radius="0.033"/>
#       </geometry>
#     </collision>
#   </link>
#   <joint name="right_wheel_joint" type="continuous">
#     <origin rpy="0 0 0" xyz="0 -0.0485 0"/>
#     <parent link="right_motor"/>
#     <child link="right_wheel_link"/>
#     <axis xyz="0 1 0"/>
#   </joint>
#   <link name="front_caster_link">
#     <inertial>
#       <origin xyz="0 0 0"/>
#       <mass value="0.001"/>
#       <inertia ixx="0.0001" ixy="0.0" ixz="0.0" iyy="0.0001" iyz="0.0" izz="0.0001"/>
#     </inertial>
#     <visual>
#       <origin rpy="1.570795 0 0" xyz="0 0 0"/>
#       <geometry>
#         <sphere radius="0.0165"/>
#       </geometry>
#       <material name="black"/>
#     </visual>
#     <collision>
#       <origin rpy="1.570795 0 0" xyz="0 0 0.01"/>
#       <geometry>
#         <sphere radius="0.0165"/>
#       </geometry>
#     </collision>
#   </link>
#   <joint name="front_caster_joint" type="fixed">
#     <origin rpy="0 0 0" xyz="0.1135 0 -0.0165"/>
#     <parent link="base_link"/>
#     <child link="front_caster_link"/>
#   </joint>
#   <joint name="standoff_2in_1_joint" type="fixed">
#     <origin rpy="0 0 0" xyz="-0.09 -0.07 0.035"/>
#     <parent link="base_link"/>
#     <child link="standoff_2in_1_link"/>
#   </joint>
#   <link name="standoff_2in_1_link">
#     <inertial>
#       <mass value="0.001"/>
#       <origin xyz="0 0 0"/>
#       <inertia ixx="0.0001" ixy="0.0" ixz="0.0" iyy="0.0001" iyz="0.0" izz="0.0001"/>
#     </inertial>
#     <visual>
#       <origin rpy="0 0 0" xyz=" 0 0 0 "/>
#       <geometry>
#         <box size="0.01 0.01 0.07"/>
#       </geometry>
#       <material name="black">
#         <color rgba="0.16 0.17 0.15 0.9"/>
#       </material>
#     </visual>
#     <collision>
#       <origin rpy="0 0 0" xyz="0.0 0.0 0.0"/>
#       <geometry>
#         <box size="0.01 0.01 0.07"/>
#       </geometry>
#     </collision>
#   </link>
#   <joint name="standoff_2in_2_joint" type="fixed">
#     <origin rpy="0 0 0" xyz="-0.09 0.07 0.035"/>
#     <parent link="base_link"/>
#     <child link="standoff_2in_2_link"/>
#   </joint>
#   <link name="standoff_2in_2_link">
#     <inertial>
#       <mass value="0.001"/>
#       <origin xyz="0 0 0"/>
#       <inertia ixx="0.0001" ixy="0.0" ixz="0.0" iyy="0.0001" iyz="0.0" izz="0.0001"/>
#     </inertial>
#     <visual>
#       <origin rpy="0 0 0" xyz=" 0 0 0 "/>
#       <geometry>
#         <box size="0.01 0.01 0.07"/>
#       </geometry>
#       <material name="black">
#         <color rgba="0.16 0.17 0.15 0.9"/>
#       </material>
#     </visual>
#     <collision>
#       <origin rpy="0 0 0" xyz="0.0 0.0 0.0"/>
#       <geometry>
#         <box size="0.01 0.01 0.07"/>
#       </geometry>
#     </collision>
#   </link>
#   <joint name="standoff_2in_3_joint" type="fixed">
#     <origin rpy="0 0 0" xyz="0.06 -0.1 0.035"/>
#     <parent link="base_link"/>
#     <child link="standoff_2in_3_link"/>
#   </joint>
#   <link name="standoff_2in_3_link">
#     <inertial>
#       <mass value="0.001"/>
#       <origin xyz="0 0 0"/>
#       <inertia ixx="0.0001" ixy="0.0" ixz="0.0" iyy="0.0001" iyz="0.0" izz="0.0001"/>
#     </inertial>
#     <visual>
#       <origin rpy="0 0 0" xyz=" 0 0 0 "/>
#       <geometry>
#         <box size="0.01 0.01 0.07"/>
#       </geometry>
#       <material name="black">
#         <color rgba="0.16 0.17 0.15 0.9"/>
#       </material>
#     </visual>
#     <collision>
#       <origin rpy="0 0 0" xyz="0.0 0.0 0.0"/>
#       <geometry>
#         <box size="0.01 0.01 0.07"/>
#       </geometry>
#     </collision>
#   </link>
#   <joint name="standoff_2in_4_joint" type="fixed">
#     <origin rpy="0 0 0" xyz="0.06 0.1 0.035"/>
#     <parent link="base_link"/>
#     <child link="standoff_2in_4_link"/>
#   </joint>
#   <link name="standoff_2in_4_link">
#     <inertial>
#       <mass value="0.001"/>
#       <origin xyz="0 0 0"/>
#       <inertia ixx="0.0001" ixy="0.0" ixz="0.0" iyy="0.0001" iyz="0.0" izz="0.0001"/>
#     </inertial>
#     <visual>
#       <origin rpy="0 0 0" xyz=" 0 0 0 "/>
#       <geometry>
#         <box size="0.01 0.01 0.07"/>
#       </geometry>
#       <material name="black">
#         <color rgba="0.16 0.17 0.15 0.9"/>
#       </material>
#     </visual>
#     <collision>
#       <origin rpy="0 0 0" xyz="0.0 0.0 0.0"/>
#       <geometry>
#         <box size="0.01 0.01 0.07"/>
#       </geometry>
#     </collision>
#   </link>
#   <joint name="plate_1_joint" type="fixed">
#     <origin rpy="0 0 0" xyz="0 0 0.07"/>
#     <parent link="base_link"/>
#     <child link="plate_1_link"/>
#   </joint>
#   <link name="plate_1_link">
#     <inertial>
#       <mass value="0.1"/>
#       <origin xyz="0 0 0"/>
#       <inertia ixx="0.01" ixy="0.0" ixz="0.0" iyy="0.01" iyz="0.0" izz="0.01"/>
#     </inertial>
#     <visual>
#       <origin rpy="0 0 0" xyz=" 0 0 0 "/>
#       <geometry>
#         <cylinder length="0.005" radius="0.13"/>
#       </geometry>
#       <material name="yellow"/>
#     </visual>
#     <collision>
#       <origin rpy="0 0 0" xyz="0.0 0.0 0.0"/>
#       <geometry>
#         <cylinder length="0.005" radius="0.13"/>
#       </geometry>
#     </collision>
#   </link>
#   <joint name="standoff_2in_5_joint" type="fixed">
#     <origin rpy="0 0 0" xyz="0 0 0.07"/>
#     <parent link="standoff_2in_1_link"/>
#     <child link="standoff_2in_5_link"/>
#   </joint>
#   <link name="standoff_2in_5_link">
#     <inertial>
#       <mass value="0.001"/>
#       <origin xyz="0 0 0"/>
#       <inertia ixx="0.0001" ixy="0.0" ixz="0.0" iyy="0.0001" iyz="0.0" izz="0.0001"/>
#     </inertial>
#     <visual>
#       <origin rpy="0 0 0" xyz=" 0 0 0 "/>
#       <geometry>
#         <box size="0.01 0.01 0.07"/>
#       </geometry>
#       <material name="black">
#         <color rgba="0.16 0.17 0.15 0.9"/>
#       </material>
#     </visual>
#     <collision>
#       <origin rpy="0 0 0" xyz="0.0 0.0 0.0"/>
#       <geometry>
#         <box size="0.01 0.01 0.07"/>
#       </geometry>
#     </collision>
#   </link>
#   <joint name="standoff_2in_6_joint" type="fixed">
#     <origin rpy="0 0 0" xyz="0 0 0.07"/>
#     <parent link="standoff_2in_2_link"/>
#     <child link="standoff_2in_6_link"/>
#   </joint>
#   <link name="standoff_2in_6_link">
#     <inertial>
#       <mass value="0.001"/>
#       <origin xyz="0 0 0"/>
#       <inertia ixx="0.0001" ixy="0.0" ixz="0.0" iyy="0.0001" iyz="0.0" izz="0.0001"/>
#     </inertial>
#     <visual>
#       <origin rpy="0 0 0" xyz=" 0 0 0 "/>
#       <geometry>
#         <box size="0.01 0.01 0.07"/>
#       </geometry>
#       <material name="black">
#         <color rgba="0.16 0.17 0.15 0.9"/>
#       </material>
#     </visual>
#     <collision>
#       <origin rpy="0 0 0" xyz="0.0 0.0 0.0"/>
#       <geometry>
#         <box size="0.01 0.01 0.07"/>
#       </geometry>
#     </collision>
#   </link>
#   <joint name="standoff_2in_7_joint" type="fixed">
#     <origin rpy="0 0 0" xyz="0 0 0.07"/>
#     <parent link="standoff_2in_3_link"/>
#     <child link="standoff_2in_7_link"/>
#   </joint>
#   <link name="standoff_2in_7_link">
#     <inertial>
#       <mass value="0.001"/>
#       <origin xyz="0 0 0"/>
#       <inertia ixx="0.0001" ixy="0.0" ixz="0.0" iyy="0.0001" iyz="0.0" izz="0.0001"/>
#     </inertial>
#     <visual>
#       <origin rpy="0 0 0" xyz=" 0 0 0 "/>
#       <geometry>
#         <box size="0.01 0.01 0.07"/>
#       </geometry>
#       <material name="black">
#         <color rgba="0.16 0.17 0.15 0.9"/>
#       </material>
#     </visual>
#     <collision>
#       <origin rpy="0 0 0" xyz="0.0 0.0 0.0"/>
#       <geometry>
#         <box size="0.01 0.01 0.07"/>
#       </geometry>
#     </collision>
#   </link>
#   <joint name="standoff_2in_8_joint" type="fixed">
#     <origin rpy="0 0 0" xyz="0 0 0.07"/>
#     <parent link="standoff_2in_4_link"/>
#     <child link="standoff_2in_8_link"/>
#   </joint>
#   <link name="standoff_2in_8_link">
#     <inertial>
#       <mass value="0.001"/>
#       <origin xyz="0 0 0"/>
#       <inertia ixx="0.0001" ixy="0.0" ixz="0.0" iyy="0.0001" iyz="0.0" izz="0.0001"/>
#     </inertial>
#     <visual>
#       <origin rpy="0 0 0" xyz=" 0 0 0 "/>
#       <geometry>
#         <box size="0.01 0.01 0.07"/>
#       </geometry>
#       <material name="black">
#         <color rgba="0.16 0.17 0.15 0.9"/>
#       </material>
#     </visual>
#     <collision>
#       <origin rpy="0 0 0" xyz="0.0 0.0 0.0"/>
#       <geometry>
#         <box size="0.01 0.01 0.07"/>
#       </geometry>
#     </collision>
#   </link>
#   <joint name="plate_2_joint" type="fixed">
#     <origin rpy="0 0 0" xyz="0 0 0.07"/>
#     <parent link="plate_1_link"/>
#     <child link="plate_2_link"/>
#   </joint>
#   <link name="plate_2_link">
#     <inertial>
#       <mass value="0.01"/>
#       <origin xyz="0 0 0"/>
#       <inertia ixx="0.001" ixy="0.0" ixz="0.0" iyy="0.001" iyz="0.0" izz="0.001"/>
#     </inertial>
#     <visual>
#       <origin rpy="0 0 0" xyz=" 0 0 0 "/>
#       <geometry>
#         <cylinder length="0.005" radius="0.13"/>
#       </geometry>
#       <material name="yellow"/>
#     </visual>
#     <collision>
#       <origin rpy="0 0 0" xyz="0.0 0.0 0.0"/>
#       <geometry>
#         <cylinder length="0.005" radius="0.13"/>
#       </geometry>
#     </collision>
#   </link>
#   <!-- rplidar -->
#   <joint name="rplidar_joint" type="fixed">
#     <origin rpy="0 0 0" xyz="0 0 0.028"/>
#     <parent link="plate_2_link"/>
#     <child link="laser_link"/>
#   </joint>
#   <link name="laser_link">
#     <inertial>
#       <mass value="0.1"/>
#       <origin xyz="0 0 0"/>
#       <inertia ixx="0.01" ixy="0.0" ixz="0.0" iyy="0.01" iyz="0.0" izz="0.01"/>
#     </inertial>
#     <visual>
#       <origin rpy="0 0 0" xyz=" 0 0 0 "/>
#       <geometry>
#         <cylinder length="0.05" radius="0.05"/>
#       </geometry>
#       <material name="black"/>
#     </visual>
#     <collision>
#       <origin rpy="0 0 0" xyz="0.0 0.0 0.0"/>
#       <geometry>
#         <cylinder length="0.06" radius="0.05"/>
#       </geometry>
#     </collision>
#   </link>
# </robot>
#
#
# /arbotix/port :  /dev/ttyUSB0
# /arbotix/baud :  115200
# /arbotix/rate :  20
# /arbotix/sync_write :  True
# /arbotix/sync_read :  True
# /arbotix/read_rate :  20
# /arbotix/write_rate :  20
# /arbotix/controllers/base_controller/type :  diff_controller
# /arbotix/controllers/base_controller/base_frame_id :  base_footprint
# /arbotix/controllers/base_controller/base_width :  0.26
# /arbotix/controllers/base_controller/ticks_meter :  4100
# /arbotix/controllers/base_controller/Kp :  12
# /arbotix/controllers/base_controller/Kd :  12
# /arbotix/controllers/base_controller/Ki :  0
# /arbotix/controllers/base_controller/Ko :  50
# /arbotix/controllers/base_controller/accel_limit :  1.0
# /arbotix/sim :  True
# /robot_state_publisher/publish_frequency :  20.0
# /move_base/global_costmap/robot_radius :  0.175
# /move_base/global_costmap/min_obstacle_height :  0.0
# /move_base/global_costmap/global_frame :  map
# /move_base/global_costmap/robot_base_frame :  base_footprint
# /move_base/global_costmap/update_frequency :  1.0
# /move_base/global_costmap/publish_frequency :  1.0
# /move_base/global_costmap/static_map :  True
# /move_base/global_costmap/rolling_window :  False
# /move_base/global_costmap/resolution :  0.01
# /move_base/global_costmap/transform_tolerance :  1.0
# /move_base/global_costmap/map_type :  costmap
# /move_base/global_costmap/obstacle_layer/max_obstacle_height :  0.6
# /move_base/global_costmap/obstacle_layer/raytrace_range :  3.0
# /move_base/global_costmap/obstacle_layer/obstacle_range :  2.5
# /move_base/global_costmap/obstacle_layer/scan/clearing :  True
# /move_base/global_costmap/obstacle_layer/scan/data_type :  LaserScan
# /move_base/global_costmap/obstacle_layer/scan/expected_update_rate :  0
# /move_base/global_costmap/obstacle_layer/scan/marking :  True
# /move_base/global_costmap/obstacle_layer/scan/topic :  /scan
# /move_base/global_costmap/obstacle_layer/observation_sources :  scan
# /move_base/global_costmap/obstacle_layer/enabled :  True
# /move_base/global_costmap/obstacle_layer/footprint_clearing_enabled :  True
# /move_base/global_costmap/obstacle_layer/combination_method :  1
# /move_base/global_costmap/inflation_layer/inflation_radius :  0.1
# /move_base/global_costmap/inflation_layer/enabled :  True
# /move_base/global_costmap/inflation_layer/cost_scaling_factor :  10.0
# /move_base/global_costmap/inflation_layer/inflate_unknown :  False
# /move_base/global_costmap/plugins :  [{'name': 'static_layer', 'type': 'costmap_2d::StaticLayer'}, {'name': 'obstacle_layer', 'type': 'costmap_2d::ObstacleLayer'}, {'name': 'inflation_layer', 'type': 'costmap_2d::InflationLayer'}]
# /move_base/global_costmap/static_layer/enabled :  True
# /move_base/global_costmap/width :  10
# /move_base/global_costmap/height :  10
# /move_base/global_costmap/origin_x :  0.0
# /move_base/global_costmap/origin_y :  0.0
# /move_base/global_costmap/footprint :  []
# /move_base/global_costmap/footprint_padding :  0.01
# /move_base/local_costmap/robot_radius :  0.175
# /move_base/local_costmap/min_obstacle_height :  0.0
# /move_base/local_costmap/global_frame :  map
# /move_base/local_costmap/robot_base_frame :  base_footprint
# /move_base/local_costmap/update_frequency :  3.0
# /move_base/local_costmap/publish_frequency :  1.0
# /move_base/local_costmap/static_map :  True
# /move_base/local_costmap/rolling_window :  False
# /move_base/local_costmap/width :  6
# /move_base/local_costmap/height :  6
# /move_base/local_costmap/resolution :  0.01
# /move_base/local_costmap/transform_tolerance :  1.0
# /move_base/local_costmap/obstacle_layer/max_obstacle_height :  0.6
# /move_base/local_costmap/obstacle_layer/raytrace_range :  3.0
# /move_base/local_costmap/obstacle_layer/obstacle_range :  2.5
# /move_base/local_costmap/obstacle_layer/scan/clearing :  True
# /move_base/local_costmap/obstacle_layer/scan/data_type :  LaserScan
# /move_base/local_costmap/obstacle_layer/scan/expected_update_rate :  0
# /move_base/local_costmap/obstacle_layer/scan/marking :  True
# /move_base/local_costmap/obstacle_layer/scan/topic :  /scan
# /move_base/local_costmap/obstacle_layer/observation_sources :  scan
# /move_base/local_costmap/obstacle_layer/enabled :  True
# /move_base/local_costmap/obstacle_layer/footprint_clearing_enabled :  True
# /move_base/local_costmap/obstacle_layer/combination_method :  1
# /move_base/local_costmap/inflation_layer/inflation_radius :  0.1
# /move_base/local_costmap/inflation_layer/enabled :  True
# /move_base/local_costmap/inflation_layer/cost_scaling_factor :  10.0
# /move_base/local_costmap/inflation_layer/inflate_unknown :  False
# /move_base/local_costmap/plugins :  [{'name': 'static_layer', 'type': 'costmap_2d::StaticLayer'}, {'name': 'obstacle_layer', 'type': 'costmap_2d::ObstacleLayer'}, {'name': 'inflation_layer', 'type': 'costmap_2d::InflationLayer'}]
# /move_base/local_costmap/static_layer/enabled :  True
# /move_base/local_costmap/origin_x :  0.0
# /move_base/local_costmap/origin_y :  0.0
# /move_base/local_costmap/footprint :  []
# /move_base/local_costmap/footprint_padding :  0.01
# /move_base/controller_frequency :  3.0
# /move_base/recovery_behavior_enabled :  False
# /move_base/clearing_rotation_allowed :  False
# /move_base/TrajectoryPlannerROS/max_vel_x :  0.5
# /move_base/TrajectoryPlannerROS/min_vel_x :  0.1
# /move_base/TrajectoryPlannerROS/max_vel_y :  0.0
# /move_base/TrajectoryPlannerROS/min_vel_y :  0.0
# /move_base/TrajectoryPlannerROS/max_vel_theta :  1.0
# /move_base/TrajectoryPlannerROS/min_vel_theta :  -1.0
# /move_base/TrajectoryPlannerROS/min_in_place_vel_theta :  0.4
# /move_base/TrajectoryPlannerROS/escape_vel :  -0.1
# /move_base/TrajectoryPlannerROS/acc_lim_x :  1.5
# /move_base/TrajectoryPlannerROS/acc_lim_y :  0.0
# /move_base/TrajectoryPlannerROS/acc_lim_theta :  1.2
# /move_base/TrajectoryPlannerROS/holonomic_robot :  False
# /move_base/TrajectoryPlannerROS/yaw_goal_tolerance :  0.1
# /move_base/TrajectoryPlannerROS/xy_goal_tolerance :  0.05
# /move_base/TrajectoryPlannerROS/latch_xy_goal_tolerance :  False
# /move_base/TrajectoryPlannerROS/pdist_scale :  0.4
# /move_base/TrajectoryPlannerROS/gdist_scale :  0.8
# /move_base/TrajectoryPlannerROS/meter_scoring :  True
# /move_base/TrajectoryPlannerROS/heading_lookahead :  0.325
# /move_base/TrajectoryPlannerROS/heading_scoring :  False
# /move_base/TrajectoryPlannerROS/heading_scoring_timestep :  0.8
# /move_base/TrajectoryPlannerROS/occdist_scale :  0.05
# /move_base/TrajectoryPlannerROS/oscillation_reset_dist :  0.05
# /move_base/TrajectoryPlannerROS/publish_cost_grid_pc :  False
# /move_base/TrajectoryPlannerROS/prune_plan :  True
# /move_base/TrajectoryPlannerROS/sim_time :  1.0
# /move_base/TrajectoryPlannerROS/sim_granularity :  0.05
# /move_base/TrajectoryPlannerROS/angular_sim_granularity :  0.1
# /move_base/TrajectoryPlannerROS/vx_samples :  8
# /move_base/TrajectoryPlannerROS/vy_samples :  0
# /move_base/TrajectoryPlannerROS/vtheta_samples :  20
# /move_base/TrajectoryPlannerROS/dwa :  True
# /move_base/TrajectoryPlannerROS/simple_attractor :  False
# /move_base/TrajectoryPlannerROS/path_distance_bias :  0.4
# /move_base/TrajectoryPlannerROS/goal_distance_bias :  0.8
# /move_base/TrajectoryPlannerROS/escape_reset_dist :  0.1
# /move_base/TrajectoryPlannerROS/escape_reset_theta :  1.5707963267948966
# /move_base/TrajectoryPlannerROS/y_vels :  -0.3,-0.1,0.1,-0.3
# /move_base/TrajectoryPlannerROS/restore_defaults :  False
# /move_base/conservative_reset/reset_distance :  3.0
# /move_base/aggressive_reset/reset_distance :  1.84
# /move_base/base_global_planner :  navfn/NavfnROS
# /move_base/base_local_planner :  base_local_planner/TrajectoryPlannerROS
# /move_base/planner_frequency :  0.0
# /move_base/planner_patience :  5.0
# /move_base/controller_patience :  5.0
# /move_base/max_planning_retries :  -1
# /move_base/conservative_reset_dist :  3.0
# /move_base/shutdown_costmaps :  False
# /move_base/oscillation_timeout :  0.0
# /move_base/oscillation_distance :  0.5
# /move_base/make_plan_clear_costmap :  True
# /move_base/make_plan_add_unreachable_goal :  True
# /move_base/restore_defaults :  False

# %%
# get a global parameter
rospy.get_param('/move_base')
# Out:
# {'global_costmap': {'robot_radius': 0.175,
#   'min_obstacle_height': 0.0,
#   'global_frame': 'map',
#   'robot_base_frame': 'base_footprint',
#   'update_frequency': 1.0,
#   'publish_frequency': 1.0,
#   'static_map': True,
#   'rolling_window': False,
#   'resolution': 0.01,
#   'transform_tolerance': 1.0,
#   'map_type': 'costmap',
#   'obstacle_layer': {'max_obstacle_height': 0.6,
#    'raytrace_range': 3.0,
#    'obstacle_range': 2.5,
#    'scan': {'clearing': True,
#     'data_type': 'LaserScan',
#     'expected_update_rate': 0,
#     'marking': True,
#     'topic': '/scan'},
#    'observation_sources': 'scan',
#    'enabled': True,
#    'footprint_clearing_enabled': True,
#    'combination_method': 1},
#   'inflation_layer': {'inflation_radius': 0.1,
#    'enabled': True,
#    'cost_scaling_factor': 10.0,
#    'inflate_unknown': False},
#   'plugins': [{'name': 'static_layer', 'type': 'costmap_2d::StaticLayer'},
#    {'name': 'obstacle_layer', 'type': 'costmap_2d::ObstacleLayer'},
#    {'name': 'inflation_layer', 'type': 'costmap_2d::InflationLayer'}],
#   'static_layer': {'enabled': True},
#   'width': 10,
#   'height': 10,
#   'origin_x': 0.0,
#   'origin_y': 0.0,
#   'footprint': '[]',
#   'footprint_padding': 0.01},
#  'local_costmap': {'robot_radius': 0.175,
#   'min_obstacle_height': 0.0,
#   'global_frame': 'map',
#   'robot_base_frame': 'base_footprint',
#   'update_frequency': 3.0,
#   'publish_frequency': 1.0,
#   'static_map': True,
#   'rolling_window': False,
#   'width': 6,
#   'height': 6,
#   'resolution': 0.01,
#   'transform_tolerance': 1.0,
#   'obstacle_layer': {'max_obstacle_height': 0.6,
#    'raytrace_range': 3.0,
#    'obstacle_range': 2.5,
#    'scan': {'clearing': True,
#     'data_type': 'LaserScan',
#     'expected_update_rate': 0,
#     'marking': True,
#     'topic': '/scan'},
#    'observation_sources': 'scan',
#    'enabled': True,
#    'footprint_clearing_enabled': True,
#    'combination_method': 1},
#   'inflation_layer': {'inflation_radius': 0.1,
#    'enabled': True,
#    'cost_scaling_factor': 10.0,
#    'inflate_unknown': False},
#   'plugins': [{'name': 'static_layer', 'type': 'costmap_2d::StaticLayer'},
#    {'name': 'obstacle_layer', 'type': 'costmap_2d::ObstacleLayer'},
#    {'name': 'inflation_layer', 'type': 'costmap_2d::InflationLayer'}],
#   'static_layer': {'enabled': True},
#   'origin_x': 0.0,
#   'origin_y': 0.0,
#   'footprint': '[]',
#   'footprint_padding': 0.01},
#  'controller_frequency': 3.0,
#  'recovery_behavior_enabled': False,
#  'clearing_rotation_allowed': False,
#  'TrajectoryPlannerROS': {'max_vel_x': 0.5,
#   'min_vel_x': 0.1,
#   'max_vel_y': 0.0,
#   'min_vel_y': 0.0,
#   'max_vel_theta': 1.0,
#   'min_vel_theta': -1.0,
#   'min_in_place_vel_theta': 0.4,
#   'escape_vel': -0.1,
#   'acc_lim_x': 1.5,
#   'acc_lim_y': 0.0,
#   'acc_lim_theta': 1.2,
#   'holonomic_robot': False,
#   'yaw_goal_tolerance': 0.1,
#   'xy_goal_tolerance': 0.05,
#   'latch_xy_goal_tolerance': False,
#   'pdist_scale': 0.4,
#   'gdist_scale': 0.8,
#   'meter_scoring': True,
#   'heading_lookahead': 0.325,
#   'heading_scoring': False,
#   'heading_scoring_timestep': 0.8,
#   'occdist_scale': 0.05,
#   'oscillation_reset_dist': 0.05,
#   'publish_cost_grid_pc': False,
#   'prune_plan': True,
#   'sim_time': 1.0,
#   'sim_granularity': 0.05,
#   'angular_sim_granularity': 0.1,
#   'vx_samples': 8,
#   'vy_samples': 0,
#   'vtheta_samples': 20,
#   'dwa': True,
#   'simple_attractor': False,
#   'path_distance_bias': 0.4,
#   'goal_distance_bias': 0.8,
#   'escape_reset_dist': 0.1,
#   'escape_reset_theta': 1.5707963267948966,
#   'y_vels': '-0.3,-0.1,0.1,-0.3',
#   'restore_defaults': False},
#  'conservative_reset': {'reset_distance': 3.0},
#  'aggressive_reset': {'reset_distance': 1.84},
#  'base_global_planner': 'navfn/NavfnROS',
#  'base_local_planner': 'base_local_planner/TrajectoryPlannerROS',
#  'planner_frequency': 0.0,
#  'planner_patience': 5.0,
#  'controller_patience': 5.0,
#  'max_planning_retries': -1,
#  'conservative_reset_dist': 3.0,
#  'shutdown_costmaps': False,
#  'oscillation_timeout': 0.0,
#  'oscillation_distance': 0.5,
#  'make_plan_clear_costmap': True,
#  'make_plan_add_unreachable_goal': True,
#  'restore_defaults': False}

# %%
# get a parameter from parent namespace
rospy.get_param('robot_state_publisher/publish_frequency')
# Out:
# 20.0

# %%
# get a parameter from private namespace
# Private parameter is set by using the ~param syntax in a <param> tag of launch file.
# The declared parameter will be set as a local parameter in a <node> tag under which it reside.

rospy.get_param('~private_param_name')

# %%
# searching for a parameter
# This gets us the closest matching parameter in terms of the namespace

full_param_name = rospy.search_param('robot_state_publisher')
param = rospy.get_param(full_param_name)
print(param)
# Out:
# {'publish_frequency': 20.0}

# %%
# set a parameter by calling rospy.set_param(param_name, param_value)

rospy.set_param('robot_state_publisher/publish_frequency', 25)

# %%
rospy.init_node('robot_state_publisher')

# !rosnode list
# Out:
# /arbotix
# /fake_localization
# /joint_state_publisher
# /log_viewer_1731761709655453268
# /map_odom_broadcaster
# /map_server
# /move_base
# /robot_state_publisher
# /rosout
# /rviz

# %%
rospy.get_param('robot_state_publisher/publish_frequency')
# Out:
# 25
